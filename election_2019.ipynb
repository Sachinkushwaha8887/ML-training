# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb

# %%
ls_data=pd.read_csv(r"C:\Users\sk414\OneDrive\Desktop\ML project\general-election-2019-main\general-election-2019-main\LokSabha.csv")

# %%
ls_data
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# ...

# %%
ls_data.shape
# Out:
# (2263, 19)

# %%
ls_data.columns
# Out:
# Index(['STATE', 'CONSTITUENCY', 'NAME', 'WINNER', 'PARTY', 'SYMBOL', 'GENDER',
#        'CRIMINAL\nCASES', 'AGE', 'CATEGORY', 'EDUCATION', 'ASSETS',
#        'LIABILITIES', 'GENERAL\nVOTES', 'POSTAL\nVOTES', 'TOTAL\nVOTES',
#        'OVER TOTAL ELECTORS \nIN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED \nIN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %%
#ls_data[ls_data["CONSTITUENCY"]=="AURANGABAD"]

# %%
ls_data["CONSTITUENCY"].value_counts()[:5]
# Out:
# AURANGABAD         14
# GAYA (SC)          12
# MAHARAJGANJ         9
# UJIARPUR            9
# SAMASTIPUR (SC)     8
# Name: CONSTITUENCY, dtype: int64

# %%
#ls_data.info()

# %%
ls_data.rename(columns={"CRIMINAL\nCASES":"Criminal"},inplace=)
# Out:
#   File "<ipython-input-31-0e1ba0e01fed>", line 1
#     ls_data.rename(columns={"CRIMINAL\nCASES":"Criminal"},inplace=)
#                                                                   ^
# SyntaxError: invalid syntax

# %%
ls_data
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# ...

# %%
#ls_data.corr()

# %%
ls_data["CRIMINAL\nCASES"].value_counts()
# Out:
# 0                1242
# 1                 313
# 2                 119
# 3                 104
# 4                  64
# 5                  42
# 6                  26
# Not Available      22
# 7                  18
# 8                  16
# 9                  11
# 10                 11
# 11                  5
# 12                  4
# 14                  4
# 13                  3
# 15                  2
# 42                  1
# 40                  1
# 41                  1
# 22                  1
# 204                 1
# 240                 1
# 52                  1
# 18                  1
# 31                  1
# 28                  1
# 24                  1
# 16                  1
# Name: CRIMINAL\nCASES, dtype: int64

# %%
ls_data["CRIMINAL\nCASES"]=ls_data["CRIMINAL\nCASES"].replace(['Not Available '],'0')
ls_data["CRIMINAL\nCASES"]=pd.to_numeric(ls_data["CRIMINAL\nCASES"],errors='coerce')

# %%
#ls_data

# %%
#ls_data["CRIMINAL\nCASES"].value_counts()

# %%
#ls_data.info()

# %%
ls_data["CRIMINAL\nCASES"].isnull().sum()
# Out:
# 267

# %%
plt.figure(figsize=(20,5))
sb.countplot(x="CRIMINAL\nCASES",data=ls_data)
plt.show()

# %%
plt.figure(figsize=(20,5))
sb.countplot(x="PARTY",data=ls_data)
plt.show()

# %%
plt.figure(figsize=(20,5))
sb.countplot(x="CRIMINAL\nCASES",data=ls_data,hue="EDUCATION")
plt.show()
